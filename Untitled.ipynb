# %%
from PIL import Image, ImageFont, ImageDraw
import urllib.request
import datetime
from time import sleep
import math
import os
from config import *
import traceback
import os
from underground import metadata, SubwayFeed
from datetime import timezone

blah_blah = 'AZnp59cTqw206YpJgG5WO2DCbHVkOTNE44V8XtJY'

times = []
out = ''

while True:
    try:
        sleep(1)
        for route in ['B','C']:
            ROUTE = route
            feed = SubwayFeed.get(ROUTE, api_key=blah_blah)
            feed = feed.dict()
            current_time = datetime.datetime.now()
            for stop in STOP_IDS:
                proceed = False
                route = UNIQUE_STOPS[STOP_IDS[stop]]
                for entity in feed['entity']:
                    if entity['trip_update'] and entity['trip_update']['stop_time_update'] is not None:
                        stops = [update['stop_id'] for update in entity['trip_update']['stop_time_update']]
                        if (route and route in stops) | (not route):
                            proceed = True
                            for update in entity['trip_update']['stop_time_update']:
                                if update['stop_id'] == stop:
                                    time = update['arrival']['time']
                                    current_time = datetime.datetime.now(timezone.utc)
                                    time = math.trunc(((time - current_time).total_seconds()) / 60)
                                    times.append(time)
                        else:
                            continue
                if proceed:
                    times.sort()
                    for time in times:
                        if time < 0:
                            times.remove(time)
                    for time in times[:NUM_TRAINS]:
                        out+=str(time)
                        out+=str(', ')
                    out = out[:-2]
                    print(STOP_IDS)
                    if route:
                        print('/home/pi/Desktop/git/subway_data/staticimages/' + STOP_IDS[stop] + '.ppm')
                        staticimg = Image.open('/home/pi/Desktop/git/subway_data/staticimages/' + STOP_IDS[stop] + '.ppm')
                    else:
                        print('herw!')
                        staticimg = Image.open('/home/pi/Desktop/git/subway_data/staticimages/' + stop[0] + stop[3] + '.ppm')

                    draw = ImageDraw.Draw(staticimg)
                    font = ImageFont.truetype('/usr/share/fonts/truetype/droid/DroidSansFallbackFull.ttf', 60)
                    draw.text((25, 4), out,(255,255,255))
                    staticimg.save('/home/pi/Desktop/git/subway_data/dynamicimages/dynamictime.ppm')
                    times = []
                    out = ''
                os.system('sudo /home/pi/Desktop/git/subway_data/rpi-rgb-led-matrix/examples-api-use/./demo --led-rows=16 --led-cols=32 --led-chain=2 -t 5 --led-brightness=20 --led-slowdown-gpio=4 -D 1 -m 0 /home/pi/Desktop/git/subway_data/dynamicimages/dynamictime.ppm')
    except Exception:
        print (traceback.format_exc())
# Out:
# > <ipython-input-1-e730f058992e>(44)<module>()
# -> if proceed:
# (Pdb) stops
# ['G08S', 'G09S', 'G10S', 'G11S', 'G12S', 'G13S', 'G14S', 'G15S', 'G16S', 'G18S', 'G19S', 'G20S', 'G21S', 'F09S', 'F11S', 'F12S', 'D15S', 'D16S', 'D17S', 'D18S', 'D19S', 'D20S', 'D21S', 'M18S', 'M16S', 'M14S', 'M13S', 'M12S', 'M11S', 'M10S', 'M09S', 'M08S', 'M06S', 'M05S', 'M04S', 'M01S']
# (Pdb) update
# *** NameError: name 'update' is not defined
# (Pdb) entity['trip_update']['stop_time_update']
# *** TypeError: 'NoneType' object is not subscriptable
# (Pdb) STOP_IDS
# {'A19S': 'BS', 'A19N': 'CS'}
# (Pdb) route
# 'D03'
# (Pdb) route
# 'D03'
# (Pdb) feed
# {'header': {'gtfs_realtime_version': '1.0', 'timestamp': datetime.datetime(2020, 11, 25, 22, 27, 58, tzinfo=datetime.timezone.utc)}, 'entity': [{'id': '000001B', 'vehicle': None, 'trip_update': {'trip': {'trip_id': '096850_B..N', 'start_time': datetime.time(16, 8, 30), 'start_date': 20201125, 'route_id': 'B'}, 'stop_time_update': [{'stop_id': 'D04N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D03N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 28, 55, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 28, 55, tzinfo=datetime.timezone.utc)}}]}}, {'id': '000002B', 'vehicle': {'trip': {'trip_id': '096850_B..N', 'start_time': datetime.time(16, 8, 30), 'start_date': 20201125, 'route_id': 'B'}, 'timestamp': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc), 'current_stop_sequence': 35, 'stop_id': 'D04'}, 'trip_update': None}, {'id': '000003B', 'vehicle': None, 'trip_update': {'trip': {'trip_id': '097500_B..N', 'start_time': datetime.time(16, 15), 'start_date': 20201125, 'route_id': 'B'}, 'stop_time_update': [{'stop_id': 'D08N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D07N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 29, 1, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 29, 1, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D06N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 30, 46, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 30, 46, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D05N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 32, 16, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 32, 16, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D04N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 33, 46, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 33, 46, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D03N', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 35, 46, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 35, 46, tzinfo=datetime.timezone.utc)}}]}}, {'id': '000004B', 'vehicle': {'trip': {'trip_id': '097500_B..N', 'start_time': datetime.time(16, 15), 'start_date': 20201125, 'route_id': 'B'}, 'timestamp': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc), 'current_stop_sequence': 31, 'stop_id': 'D08'}, 'trip_update': None}, {'id': '000005B', 'vehicle': None, 'trip_update': {'trip': {'trip_id': '097550_B..S', 'start_time': datetime.time(16, 15, 30), 'start_date': 20201125, 'route_id': 'B'}, 'stop_time_update': [{'stop_id': 'D35S', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D39S', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 35, 21, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 35, 21, tzinfo=datetime.timezone.utc)}}, {'stop_id': 'D40S', 'arrival': {'time': datetime.datetime(2020, 11, 25, 22, 38, 21, tzinfo=datetime.timezone.utc)}, 'departure': {'time': datetime.datetime(2020, 11, 25, 22, 38, 21, tzinfo=datetime.timezone.utc)}}]}}, {'id': '000006B', 'vehicle': {'trip': {'trip_id': '097550_B..S', 'start_time': datetime.time(16, 15, 30), 'start_date': 20201125, 'route_id': 'B'}, 'timestamp': datetime.datetime(2020, 11, 25, 22, 27, 51, tzinfo=datetime.timezone.utc), 'current_stop_sequence': 34, 'stop_id': 'D35'}, 'trip_update': None}, {'id': ...
# (Pdb) feed.dict()
# *** AttributeError: 'dict' object has no attribute 'dict'
# (Pdb) type(feed)
# <class 'dict'>
# (Pdb) STOP_IDS
# {'A19S': 'BS', 'A19N': 'CS'}
# (Pdb) STOP_IDS[stop]
# 'BS'
# (Pdb) '/home/pi/Desktop/git/subway_data/staticimages/' + STOP_IDS[stop] + '.ppm'
# '/home/pi/Desktop/git/subway_data/staticimages/BS.ppm'
# (Pdb) q
# Traceback (most recent call last):
#   File "<ipython-input-1-e730f058992e>", line 44, in <module>
#     if proceed:
#   File "<ipython-input-1-e730f058992e>", line 44, in <module>
#     if proceed:
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 88, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 113, in dispatch_line
#     if self.quitting: raise BdbQuit
# bdb.BdbQuit
#
# > <ipython-input-1-e730f058992e>(43)<module>()
# -> import pdb; pdb.set_trace()
# (Pdb) q
# Traceback (most recent call last):
#   File "<ipython-input-1-e730f058992e>", line 43, in <module>
#     import pdb; pdb.set_trace()
#   File "<ipython-input-1-e730f058992e>", line 43, in <module>
#     import pdb; pdb.set_trace()
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 88, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 113, in dispatch_line
#     if self.quitting: raise BdbQuit
# bdb.BdbQuit
#
# > <ipython-input-1-e730f058992e>(44)<module>()
# -> if proceed:
# (Pdb) q
# Traceback (most recent call last):
#   File "<ipython-input-1-e730f058992e>", line 44, in <module>
#     if proceed:
#   File "<ipython-input-1-e730f058992e>", line 44, in <module>
#     if proceed:
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 88, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 113, in dispatch_line
#     if self.quitting: raise BdbQuit
# bdb.BdbQuit
#
# > <ipython-input-1-e730f058992e>(43)<module>()
# -> import pdb; pdb.set_trace()
# (Pdb) q
# Traceback (most recent call last):
#   File "<ipython-input-1-e730f058992e>", line 43, in <module>
#     import pdb; pdb.set_trace()
#   File "<ipython-input-1-e730f058992e>", line 43, in <module>
#     import pdb; pdb.set_trace()
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 88, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 113, in dispatch_line
#     if self.quitting: raise BdbQuit
# bdb.BdbQuit
#
# > <ipython-input-1-e730f058992e>(44)<module>()
# -> if proceed:
# (Pdb) q
# Traceback (most recent call last):
#   File "<ipython-input-1-e730f058992e>", line 44, in <module>
#     if proceed:
#   File "<ipython-input-1-e730f058992e>", line 44, in <module>
#     if proceed:
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 88, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 113, in dispatch_line
#     if self.quitting: raise BdbQuit
# bdb.BdbQuit
#
# > <ipython-input-1-e730f058992e>(43)<module>()
# -> import pdb; pdb.set_trace()
# (Pdb)
# (Pdb) q
# Traceback (most recent call last):
#   File "<ipython-input-1-e730f058992e>", line 43, in <module>
#     import pdb; pdb.set_trace()
#   File "<ipython-input-1-e730f058992e>", line 43, in <module>
#     import pdb; pdb.set_trace()
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 88, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/Users/cholmes/anaconda3/lib/python3.7/bdb.py", line 113, in dispatch_line
#     if self.quitting: raise BdbQuit
# bdb.BdbQuit
#
# > <ipython-input-1-e730f058992e>(44)<module>()
# -> if proceed:
